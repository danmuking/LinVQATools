# %% [markdown]
# # 相似度分析

# %%
import os

# %%
root = '/data/ly/unique/VQA_ODV'
video_list = [os.path.join(root,i) for i in os.listdir(root)]
for i in video_list:
    print(os.listdir(i))
# Out:
# ['G9BloomingAppleOrchards_RCMP_7680x3840_fps29.97_qp37_1555k_ERP', 'G9ConcertLive_ERP_4096x2048_fps30_qp37_2256k', 'G9DrivingInCity_RCMP_3840x1920_fps30_qp27_10899k_ERP', 'G9DivingWithJellyfish_ERP_7680x3840_fps25_qp37_2228k', 'G9DrivingInCity_TSP_3840x1920_fps30_qp27_12713k_ERP', 'G9ConcertLive_TSP_4096x2048_fps30_qp27_8373k_ERP', 'G9GreatWall_ERP_4096x2048_fps30_qp27_43911k', 'G9DrivingInCity_RCMP_3840x1920_fps30_qp37_2331k_ERP', 'G9DrivingInCity_RCMP_3840x1920_fps30_qp42_1068k_ERP', 'G9GreatWall_RCMP_4096x2048_fps30_qp27_33606k_ERP', 'G9BloomingAppleOrchards_ERP_7680x3840_fps29.97_qp27_16794k', 'G9FootballMatch_TSP_4096x2048_fps30_qp37_263k_ERP', 'G9FootballMatch_ERP_4096x2048_fps30_qp37_220k', 'G9FootballMatch_ERP_4096x2048_fps30_qp42_288k', 'G9FootballMatch_ERP_4096x2048_fps30_qp27_1529k', 'G9ConcertLive_RCMP_4096x2048_fps30_qp27_6973k_ERP', 'G9BloomingAppleOrchards_ERP_7680x3840_fps29.97_qp37_1837k', 'G9GreatWall_ERP_4096x2048_fps30_qp42_3096k', 'G9DrivingInCity_TSP_3840x1920_f
# ...
